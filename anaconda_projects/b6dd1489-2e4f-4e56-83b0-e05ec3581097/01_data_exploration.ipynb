# %%
from datasets import load_dataset
import pandas as pd

# Download the Digital Music subset of Amazon Reviews
# ~65K reviews, clean, balanced enough for our purposes
print("Downloading dataset...")
dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", 
                       "raw_review_Digital_Music",
                       trust_remote_code=True)

print(dataset)
print("\nFirst review:")
print(dataset['full'][0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from datasets import load_dataset
#       2 import pandas as pd
#       4 # Download the Digital Music subset of Amazon Reviews
#       5 # ~65K reviews, clean, balanced enough for our purposes
#
# ModuleNotFoundError: No module named 'datasets'
